# %%
from chembl_webresource_client.new_client import new_client
import pandas as pd 
from chembl_webresource_client.settings import Settings 
Settings.Instance().CACHING = False 
target = new_client.target
mechanism = new_client.mechanism
molecule = new_client.molecule 
activity = new_client.activity 


target_search = target.search('Sigma Non-Opioid Intracellular Receptor 1').only('target_chembl_id', 'target_organism')[:20]
target_df = pd.DataFrame(target_search)
print(target_df)


target_real= 'CHEMBL287'
#finding all molecule thats bids t the target

activities = activity.filter(target_chembl_id= [target_real]
                             , pchembl_value__gte = 7
                             , assay_type = 'B')\
                             .only('target_pref_name','pchembl_value', 'assay_type', 'molecule_chembl_id', 'parent_molecule_chembl_id', 'action_type' )
df = pd.DataFrame(activities)
print(df)


df.to_csv('target_file1.csv', index = False )
# Out:
# /home/ajibola_linux/miniconda3/envs/cadd/lib/python3.9/site-packages/chembl_webresource_client/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __version__ = __import__('pkg_resources').get_distribution('chembl_webresource_client').version
#              organism target_chembl_id
# 0        Mus musculus       CHEMBL3465
# 1   Rattus norvegicus       CHEMBL3602
# 2     Cavia porcellus       CHEMBL4153
# 3        Homo sapiens        CHEMBL287
# 4        Homo sapiens    CHEMBL4524009
# 5   Rattus norvegicus    CHEMBL4105864
# 6        Mus musculus    CHEMBL4802011
# 7          Bos taurus    CHEMBL5465309
# 8        Homo sapiens    CHEMBL4105907
# 9   Rattus norvegicus    CHEMBL2095155
# 10  Rattus norvegicus    CHEMBL2094129
# 11       Homo sapiens    CHEMBL2095181
# 12       Homo sapiens        CHEMBL233
# 13  Rattus norvegicus        CHEMBL269
# 14  Rattus norvegicus        CHEMBL270
# 15       Homo sapiens    CHEMBL2095149
# 16       Homo sapiens    CHEMBL2095156
# 17    Cavia porcellus    CHEMBL2111465
# 18  Rattus norvegicus    CHEMBL3038507
# 19    Cavia porcellus    CHEMBL3038518
#     action_type assay_type molecule_chembl_id parent_molecule_chembl_id  \
# 0          None          B        CHEMBL38904               CHEMBL38904
# 1          None          B        CHEMBL67010               CHEMBL67010
# 2          None          B       CHEMBL542638             CHEMBL1191528
# 3          None          B        CHEMBL45962               CHEMBL45962
# 4          None          B        CHEMBL45686               CHEMBL45686
# ..          ...        ...                ...                       ...
# 595        None          B       CHEMBL118797              CHEMBL118797
# 596        None          B       CHEMBL290675              CHEMBL290675
# 597        None          B        CHEMBL60542               CHEMBL60542
# 598        None          B       CHEMBL287794              CHEMBL287794
# 599        None          B        CHEMBL41313               CHEMBL41313
#
#     pchembl_value                           target_pref_name  type value
# 0            7.70  Sigma non-opioid intracellular receptor 1    Ki  20.0
# 1            7.14  Sigma non-opioid intracellular receptor 1  IC50  72.0
# 2            8.22  Sigma non-opioid intracellular receptor 1  IC50   6.0
# 3            7.47  Sigma non-opioid intracellular receptor 1    Ki  34.0
# 4            7.72  Sigma non-opioid intracellular receptor 1    Ki  19.0
# ..            ...                                        ...   ...   ...
# 595          8.37  Sigma non-opioid intracellular receptor 1    Ki   4.3
# 596          7.70  Sigma non-opioid intracellular receptor 1    Ki  20.1
# 597          8.21  Sigma non-opioid intracellular receptor 1    Ki   6.1
# 598          8.23  Sigma non-opioid intracellular receptor 1    Ki   5.9
# 599          8.02  Sigma non-opioid intracellular receptor 1    Ki   9.6
#
# [600 rows x 8 columns]
