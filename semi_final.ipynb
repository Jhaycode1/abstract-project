# %%
from chembl_webresource_client.new_client import new_client
import pandas as pd 
from chembl_webresource_client.settings import Settings 
Settings.Instance().CACHING = False 
target = new_client.target
mechanism = new_client.mechanism
molecule = new_client.molecule 
activity = new_client.activity 


target_search = target.search('Sigma Non-Opioid Intracellular Receptor 1').only('target_chembl_id', 'target_organism')[:20]
target_df = pd.DataFrame(target_search)
print(target_df)


target_real= 'CHEMBL287'
#finding all that binds to target

activities = activity.filter(target_chembl_id = target_real).only('molecule_chembl_id', 'molecule_pref_name', 'parent_molecule_chembl_id')
activities_df = pd.DataFrame(activities)
print(activities_df)

activities_df.to_csv('activites.csv', index = False)
print('activities_df saved')

my_molecule= pd.read_csv('activities.csv')
molecules = my_molecule['molecule_chembl_id'].tolist()

mec = mechanism.filter(molecule_chembl_id__in= molecules).only('action_type', 'molecule_chembl_id', 'parent_molecule_chembl_id')
mec_df = pd.DataFrame(mec)
print(mec_df)
mec_df.to_csv('mechanisms.csv', index = False)
print('mechanisms.csv saved')

mole= pd.read_csv('mechanisms.csv')
final_mole = mole['molecule_chembl_id'].tolist()
mol= molecule.filter(molecule_chembl_id__in = final_mole).only('molecule_chembl_id', 'max_phase', 'pref_name')
mol_df = pd.DataFrame(mol)
mol_df.to_csv('molecule.csv', index = False)
print('molecule.csv saved')
# Out:
# /home/ajibola_linux/miniconda3/envs/cadd/lib/python3.9/site-packages/chembl_webresource_client/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __version__ = __import__('pkg_resources').get_distribution('chembl_webresource_client').version
#              organism target_chembl_id
# 0        Mus musculus       CHEMBL3465
# 1   Rattus norvegicus       CHEMBL3602
# 2     Cavia porcellus       CHEMBL4153
# 3        Homo sapiens        CHEMBL287
# 4        Homo sapiens    CHEMBL4524009
# 5   Rattus norvegicus    CHEMBL4105864
# 6        Mus musculus    CHEMBL4802011
# 7          Bos taurus    CHEMBL5465309
# 8        Homo sapiens    CHEMBL4105907
# 9   Rattus norvegicus    CHEMBL2095155
# 10  Rattus norvegicus    CHEMBL2094129
# 11       Homo sapiens    CHEMBL2095181
# 12       Homo sapiens        CHEMBL233
# 13  Rattus norvegicus        CHEMBL269
# 14  Rattus norvegicus        CHEMBL270
# 15       Homo sapiens    CHEMBL2095149
# 16       Homo sapiens    CHEMBL2095156
# 17    Cavia porcellus    CHEMBL2111465
# 18  Rattus norvegicus    CHEMBL3038507
# 19    Cavia porcellus    CHEMBL3038518
#      molecule_chembl_id molecule_pref_name parent_molecule_chembl_id
# 0           CHEMBL38904               None               CHEMBL38904
# 1           CHEMBL38904               None               CHEMBL38904
# 2           CHEMBL67010               None               CHEMBL67010
# 3          CHEMBL542638               None             CHEMBL1191528
# 4           CHEMBL46169               None               CHEMBL46169
# ...                 ...                ...                       ...
# 8850      CHEMBL6047123               None             CHEMBL6047123
# 8851      CHEMBL6047123               None             CHEMBL6047123
# 8852      CHEMBL6018971               None             CHEMBL6018971
# 8853      CHEMBL6018971               None             CHEMBL6018971
# 8854      CHEMBL6018971               None             CHEMBL6018971
#
# [8855 rows x 3 columns]
# activities_df saved
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 26
#      23 activities_df.to_csv('activites.csv', index = False)
#      24 print('activities_df saved')
# ---> 26 my_molecule= pd.read_csv('activities.csv')
#      27 molecules = my_molecule['molecule_chembl_id'].tolist()
#      29 mec = mechanism.filter(molecule_chembl_id__in= molecules).only('action_type', 'molecule_chembl_id', 'parent_molecule_chembl_id')
#
# File ~/miniconda3/envs/cadd/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/cadd/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/envs/cadd/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/cadd/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniconda3/envs/cadd/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'activities.csv'
